# %%
# Dados do post: Legenda do post, coautores, num_comentarios, hashtags, comentarios habiliados, num_likes, mençoes, nome do owner, timestamp, tipo, url, visualizações, duracao do video, localização

# Comentarios do post: Texto do comentario, username do owner, timestamp, replies, likescount

# Dados do owner do comentario (unico)

# Um arquivo de dados do post, um arquivo de comentarios e um arquivo de dados do owner do comment por post

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 13
#       9
#      10 post = full_data[["caption", "coauthorProducers", "commentsCount", "hashtags", "isCommentsDisabled", "likesCount", "mentions", "timestamp", "type", "url", "videoViewCount", "videoDuration", "locationName"]]
#      11 comment_data = full_data["latestComments"]
#      12 for data in comment_data.items():
# ---> 13     comment = data[1]["text"]
#      14     print(comment)
#      15
#      16 """
#
# TypeError: list indices must be integers or slices, not str

# %%
full_data
# Out:
#                                               caption  \
# 0   📢 EDITAL ABERTO – TESTE TOEFL ITP UFSM! 🌍✍️\nV...
# 1   🎉 Viva o Campus – Lançamento 50 anos de Extens...
# 2   O 38º Carijo da Canção Gaúcha movimentou Palme...
# 3   O Silveira já virou celebridade: circula pelo ...
# 4   Santa Maria recebe Festival Internacional de C...
# 5   🥳 MAIS UMA CHANCE PARA INGRESSAR NA UFSM!!\n\n...
# 6   Silveira representando todas as diferentes emo...
# 7   Na última sexta-feira (23), a UFSM celebrou o ...
# 8   🥰 Mandem meus presentinho para:\nAv Roraima 10...
# 9   “Se perder? Aqui não! 🧭📍Aprenda o caminho até ...
# 10  🎉 O Viva o Campus está de volta — agora na Ant...
# 11  PRÓ-REITOR DE ASSUNTOS CANINOS NA MÍDIA 🐶🌐\n\n...
# 12  Congresso internacional sobre turismo rural mo...
# 13  📢 Inscrições abertas para a 3ª janela da pós-g...
# 14  Tem que ser com jeitinho para tirar foto com a...
# 15  Você conhece os aumigos do Silveira? 🐶 🐾\n\nNe...
# ...
